# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd
import numpy as np
from math import log10

# %%
models_label = ['Random Forest Regression','Random Forest Regression','Linear Regression','Linear Regression','Logistic Regression','Logistic Regression',
                'LSTM Lookback=1','LSTM Lookback=1','LSTM Lookback=5','LSTM Lookback=5',
                'LSTM Lookback=10','LSTM Lookback=10']
VAR = ['Without VAR','With VAR','Without VAR','With VAR','Without VAR','With VAR',
       'Without VAR','With VAR','Without VAR','With VAR','Without VAR','With VAR']
MSE = [3179.9, 788.57,
       2747.63, 1233.97,
       2454.39, 1262.74,
       1082.23, 773.07,
       1854.72, 2589.95,
       1694.33, 1688.7]
RMSE = [56.39,28.08,
        52.41,35.12,
        49.54,35.53,
        32.89,27.8,
        43.06,50.89,
        41.16,41.0]
MAE = [49.34,22.37,
       44.35,28.48,
       40.5,28.68,
       26.39,21.45,
       33.38,41.51,
       32.39,29.34]
scoring_function = [327970.27,1986.47,
                    282257.88,5721.58,
                    210561.72,5285.39,
                    3819.08,2131.60,
                    991089.91,43056.87,
                    173798.23,8879551.74]

log_scoring_function = []
for s in scoring_function:
    log_scoring_function.append(np.round(log10(s),3))

# %%
dict = {'Model': models_label, 'With/Without VAR': VAR, 'MSE': MSE, 'RMSE':RMSE, 'MAE':MAE, 'Log10 of Scoring Function':log_scoring_function} 
# df = pd.DataFrame(models_label,VAR,MSE,RMSE,MAE,scoring_function)

# %%
df = pd.DataFrame(dict)
df
# Out:
#                        Model With/Without VAR      MSE   RMSE    MAE  \
# 0   Random Forest Regression      Without VAR  3179.90  56.39  49.34
# 1   Random Forest Regression         With VAR   788.57  28.08  22.37
# 2          Linear Regression      Without VAR  2747.63  52.41  44.35
# 3          Linear Regression         With VAR  1233.97  35.12  28.48
# 4        Logistic Regression      Without VAR  2454.39  49.54  40.50
# 5        Logistic Regression         With VAR  1262.74  35.53  28.68
# 6            LSTM Lookback=1      Without VAR  1082.23  32.89  26.39
# 7            LSTM Lookback=1         With VAR   773.07  27.80  21.45
# 8            LSTM Lookback=5      Without VAR  1854.72  43.06  33.38
# 9            LSTM Lookback=5         With VAR  2589.95  50.89  41.51
# 10          LSTM Lookback=10      Without VAR  1694.33  41.16  32.39
# 11          LSTM Lookback=10         With VAR  1688.70  41.00  29.34
#
#     Log10 of Scoring Function
# 0                       5.516
# 1                       3.298
# 2                       5.451
# 3                       3.758
# 4                       5.323
# 5                       3.723
# 6                       3.582
# 7                       3.329
# 8                       5.996
# 9                       4.634
# 10                      5.240
# 11                      6.948

# %%
ax = sns.barplot(x="Model", y="MSE", hue="With/Without VAR", data=df)
plt.xticks(rotation=90)
plt.ylabel("Mean Sqaure Error", fontsize=12)
# Out:
# Text(0, 0.5, 'Mean Sqaure Error')

# %%
ax = sns.barplot(x="Model", y="RMSE", hue="With/Without VAR", data=df)
plt.xticks(rotation=90)
plt.ylabel("Root Mean Square Error", fontsize=12)
# Out:
# Text(0, 0.5, 'Root Mean Square Error')

# %%
ax = sns.barplot(x="Model", y="MAE", hue="With/Without VAR", data=df)
plt.xticks(rotation=90)
plt.ylabel("Mean Aboslute Error", fontsize=12)
# Out:
# Text(0, 0.5, 'Mean Aboslute Error')

# %%
ax = sns.barplot(x="Model", y="Log10 of Scoring Function", hue="With/Without VAR", data=df)
plt.xticks(rotation=90)

plt.ylabel("Log10 of Scoring Function Value", fontsize=12)
# Out:
# Text(0, 0.5, 'Log10 of Scoring Function Value')

# %%
list(zip(models_label,VAR,log_scoring_function))
# Out:
# [('Random Forest Regression', 'Without VAR', 5.516),
#  ('Random Forest Regression', 'With VAR', 3.298),
#  ('Linear Regression', 'Without VAR', 5.451),
#  ('Linear Regression', 'With VAR', 3.758),
#  ('Logistic Regression', 'Without VAR', 5.323),
#  ('Logistic Regression', 'With VAR', 3.723),
#  ('LSTM Lookback=1', 'Without VAR', 3.582),
#  ('LSTM Lookback=1', 'With VAR', 3.329),
#  ('LSTM Lookback=5', 'Without VAR', 5.996),
#  ('LSTM Lookback=5', 'With VAR', 4.634),
#  ('LSTM Lookback=10', 'Without VAR', 5.24),
#  ('LSTM Lookback=10', 'With VAR', 6.948)]
