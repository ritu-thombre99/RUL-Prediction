# %% [markdown]
# # Run to Failure degradation simulation of NASA Turbo Jet Engine Fans

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import math
import matplotlib.pyplot as plt
from matplotlib import cm

import statsmodels.api as sm
from statsmodels.tsa.stattools import acf, pacf
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.vector_ar.var_model import VAR

from sklearn.decomposition import PCA
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import QuantileTransformer , PowerTransformer
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import KFold

from keras import optimizers
from keras.models import Sequential
from keras.layers import TimeDistributed, Flatten
from keras.layers.core import Dense, Dropout, Activation
from keras.layers.recurrent import LSTM
from sklearn.metrics import mean_squared_error

import warnings 
warnings.filterwarnings('ignore')

# %matplotlib inline
cmap = cm.get_cmap('Spectral') # Colour map (there are many others)

from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score

from keras.models import load_model
import pickle

# %%
train_file = "train_FD001.txt" 
test_file = "test_FD001.txt"
RUL_file = "RUL_FD001.txt"

# %%
model = pickle.load(open('logistic_regression.sav', 'rb'))

# %%
df_test = pd.read_csv(test_file, sep=" ",header=None)
df_test.drop(columns=[26,27],inplace=True)
columns = ["Section-{}".format(i)  for i in range(26)]
df_test.columns = columns
# df_test.head()

# %%
df_test_rul = pd.read_csv(RUL_file, names=['rul'])
# df_test_rul.head()

# %%
RUL_name = ["Section-1"]
RUL_data = df_test[RUL_name]
MachineID_series = df_test["Section-0"]
grp = RUL_data.groupby(MachineID_series)
max_cycles = np.array([max(grp.get_group(i)["Section-1"]) for i in MachineID_series.unique()])

# %%
df_test.drop(df_test[["Section-0",
                "Section-4", # Operatinal Setting
                "Section-5", # Sensor data
                "Section-9", # Sensor data
                "Section-10", # Sensor data
                "Section-14",# Sensor data
                "Section-20",# Sensor data
                "Section-22",# Sensor data
                "Section-23"]], axis=1 , inplace=True)
#df_test = df_test.groupby(["Section-0"])
#print(df_test)

# %%
gen = MinMaxScaler(feature_range=(0, 1))
df_test = gen.fit_transform(df_test)
df_test = pd.DataFrame(df_test)
#df_test = df_test.rolling(20).mean()
pt = PowerTransformer()
df_test = pt.fit_transform(df_test)
df_test=np.nan_to_num(df_test)

# %%
test_data = []
i = 0
count = 0
while i < len(df_test):
    temp = []
    j = int(max_cycles[count])
    count = count+1
    #print(j)
    if j == 0:
        break
    while j!=0:
        temp.append(df_test[i])
        i=i+1
        j=j-1
    test_data.append(temp)

# %%
print(len(test_data))
# Out:
# 100

# %%
y_new = []
for i in range(len(test_data)):
    y_new.append(pd.DataFrame(test_data[i]))

y_new[1]
# Out:
#           0         1         2         3         4         5         6   \
# 0  -1.793850 -0.403908  1.327938  0.491476  0.264432  0.414832 -0.930599
# 1  -1.759832 -0.494678  0.677007  0.124510  0.091941  0.167868 -0.390194
# 2  -1.726093  0.095455  1.004600  0.297019  1.470300  0.931735 -0.658122
# 3  -1.692628  1.140251  0.344897 -0.381088 -0.930734  0.567578  0.546454
# 4  -1.659435  0.186271 -1.395065  0.754319 -0.597428  0.477975  0.280052
# 5  -1.626511 -0.358520 -1.035151  0.099683 -1.694581 -0.320162 -0.009098
# 6  -1.593852  0.867611  0.007977  0.418886  1.223617  0.154514 -0.347077
# 7  -1.561456  0.685883  1.004600  0.370273 -0.972818  0.034889 -0.903790
# 8  -1.529320 -0.993778  1.004600 -0.458622  0.153580  0.469392 -0.781945
# 9  -1.497440  0.958485  1.327938  0.174027  0.571892  0.251963 -0.504089
# 10 -1.465814 -0.449294  0.007977  0.272511  1.285571  0.467961 -0.216388
# 11 -1.434440  1.003924 -0.334082  0.587653  2.099453  1.091485 -0.201744
# 12 -1.403314  1.549319  0.344897 -0.278413 -0.823847 -0.274779 -0.231008
# 39  1.488525 -0.629702  0.340425  0.238079  0.878242 -1.237652 -0.194514
# 40  0.212695 -1.813448  0.190295 -0.551675  0.549714 -1.530225  0.004742
# 41  0.382663 -1.379432  0.240686 -0.483046  1.195698 -1.365348  1.739433
# 42  0.713093 -0.717233  0.726022 -0.819951  1.350488 -1.520225  2.145515
# 43  0.873772 -0.774179  1.180128 -1.372477  1.038310 -0.648021  0.409725
# 44  0.382663 -1.258645  0.487480 -0.237888  0.549714 -1.152790  0.742428
# 45  0.713093 -1.344230  0.088446 -1.250293  0.549714 -1.073174  0.703407
# 46 -0.137329 -0.487638  0.487480  0.861409  0.715408 -1.079764 -0.085710
# 47  1.780351 -1.161545  0.190295 -0.803475  0.715408 -1.507394  0.735934
# 48  0.549425 -1.423107  1.267495 -0.076189  0.381065 -1.332113  0.865118
#
#           14        15        16
# 0  -0.435852  0.748684  0.655920
# 1   0.378493 -0.405454 -0.574031
# 2   1.148940  0.899581  0.835040
# 3   0.378493 -0.543059  1.669632
# 4  -0.435852 -0.611304  0.620619
# 5  -0.435852 -0.813804 -0.816911
# 6   0.378493 -1.012946  2.391391
# 7  -1.300958 -0.746677 -1.308672
# 8  -0.435852 -1.273230 -0.769650
# 9  -0.435852  0.159801  0.009971
# 10 -0.435852 -0.611304  0.038878
# 11 -0.435852 -0.746677 -0.634664
# 12  0.378493  0.016267 -0.263757
# 13  0.378493  0.232122  0.106581
# 14  1.148940 -0.196261  0.664760
# 15  0.378493 -0.266363  0.266342
# 16 -0.435852 -1.273230 -0.914177
# 17 -0.435852 -0.474443 -1.278598
# 18 -0.435852 -0.880558 -0.295499
# 19  0.378493 -0.880558 -1.031533
# 20  1.148940 -0.054946  0.546523
# 21  0.378493 -0.125789 -1.053534
# 22  0.378493  0.823949 -0.235473
# 23 -0.435852  0.975580 -0.760625
# 24 -0.435852 -0.266363  0.485285
# 25 -0.435852  0.232122 -1.132364
# 26  0.378493 -0.543059 -0.508468
# 27  0.378493 -0.946939  0.217355
# 28  1.148940  0.748684 -0.420480
# 29  0.378493  0.232122 -0.405364
# 30  1.148940 -1.078579 -0.385569
# 31  1.148940 -1.078579 -0.299020
# 32  1.880977  0.899581 -0.375076
# 33 -0.435852  0.525093 -0.987396
# 34  0.378493 -0.196261 -0.375076
# 35  0.378493 -0.405454 -1.305454
# 36  0.378493  0.899581 -0.599238
# 37  0.378493 -0.611304  0.304432
# 38  1.148940 -1.527509 -0.377408
# 39  0.378493 -1.078579  0.368569
# 40  0.378493 -0.543059  0.024416
# 41  0.378493 -0.125789 -1.355752
# 42 -0.435852 -1.143837 -0.718793
# 43 -0.435852 -0.746677  0.172202
# 44 -0.435852  0.377871 -0.569442
# 45  1.148940 -0.125789 -1.233323
# 46 -0.435852 -0.125789 -0.501545
# 47 -0.435852  0.673786 -0.555664
# 48 -1.300958 -0.611304 -0.895238

# %%
predictions = []
for i in range(len(y_new)):
    test_model = VAR(y_new[i])
    test_model_fit = test_model.fit()
    test_pred = test_model_fit.forecast(test_model_fit.y, steps=1)
    predictions.append(test_pred)

# %%
predictions[0].shape
# Out:
# (1, 17)

# %%
logistic_pred = []
for i in range(100):
    logistic_pred.append(model.predict(predictions[i]))
#logistic_pred = np.array(logistic_pred)

# %%
logistic_pred = np.array(logistic_pred)

# %%
len(logistic_pred)
# Out:
# 100

# %%
y_test = np.array(df_test_rul)

# %%
len(y_test)
# Out:
# 100

# %%
fig = plt.figure(figsize=(18,10))
plt.plot(logistic_pred,color='red', label='prediction')
plt.plot(y_test,color='blue', label='y_test')

fig.suptitle('RUL Prediction using VAR Model with Logistic Regression', fontsize=35)
plt.xlabel("Engine Number", fontsize=35)
plt.ylabel("Remaining Useful Life", fontsize=35)

plt.legend(loc='upper left')
plt.grid()
plt.show()

# %%
def scoring_function(actual,predicted):
    d = []
    for i in range(len(predicted)):
        d.append((predicted[i] - actual[i]))
    scores = []
    for i in range(len(d)):
        if d[i] >= 0:
            scores.append(math.exp(d[i]/10) - 1)
        else :
            scores.append(math.exp((-1*d[i])/13) - 1)
    return sum(scores)

print("mean_squared_error >> ", mean_squared_error(y_test,logistic_pred))
print("root_mean_squared_error >> ", math.sqrt(mean_squared_error(y_test,logistic_pred)))
print("mean_absolute_error >>",mean_absolute_error(y_test,logistic_pred))
print("scoring function >>",scoring_function(y_test,logistic_pred))
# Out:
# mean_squared_error >>  1262.74
# root_mean_squared_error >>  35.535053116605866
# mean_absolute_error >> 28.68
# scoring function >> 5285.391201712641

# %% [markdown]
# # 6. Health Score Assignment

# %%
health_scores = []
for i in range(len(logistic_pred)):
    if logistic_pred[i] >= 100:
        health_scores.append(1)
    else:
        health_scores.append(float(logistic_pred[i])/100)

# %%
print(health_scores)
# Out:
# [1, 0.46, 0.32, 0.57, 0.47, 0.55, 0.68, 0.56, 0.49, 0.56, 0.4, 0.59, 0.55, 0.52, 0.98, 0.81, 0.34, 0.25, 0.73, 0.01, 0.77, 1, 0.9, 0.27, 1, 1, 0.9, 0.45, 0.63, 0.48, 0.01, 0.46, 0.3, 0.01, 0.01, 0.01, 0.16, 0.18, 1, 0.08, 0.25, 0.01, 0.32, 0.81, 0.46, 0.34, 0.52, 0.96, 0.01, 0.83, 0.68, 0.18, 0.15, 0.83, 0.7, 0.02, 0.52, 0.18, 1, 0.57, 0.14, 0.37, 0.34, 0.13, 1, 0.02, 1, 0.01, 1, 0.54, 0.93, 0.49, 0.93, 0.54, 0.86, 0.01, 0.14, 1, 0.93, 0.46, 0.01, 0.01, 0.88, 0.32, 0.75, 0.45, 1, 0.48, 0.49, 0.06, 0.07, 0.01, 0.21, 0.25, 0.96, 0.86, 0.58, 0.31, 0.95, 0.15]

# %%
for i in range(len(health_scores)):
    print("Health scores of Engine no.",i+1,'is :',health_scores[i])
# Out:
# Health scores of Engine no. 1 is : 1
# Health scores of Engine no. 2 is : 0.46
# Health scores of Engine no. 3 is : 0.32
# Health scores of Engine no. 4 is : 0.57
# Health scores of Engine no. 5 is : 0.47
# Health scores of Engine no. 6 is : 0.55
# Health scores of Engine no. 7 is : 0.68
# Health scores of Engine no. 8 is : 0.56
# Health scores of Engine no. 9 is : 0.49
# Health scores of Engine no. 10 is : 0.56
# Health scores of Engine no. 11 is : 0.4
# Health scores of Engine no. 12 is : 0.59
# Health scores of Engine no. 13 is : 0.55
# Health scores of Engine no. 14 is : 0.52
# Health scores of Engine no. 15 is : 0.98
# Health scores of Engine no. 16 is : 0.81
# Health scores of Engine no. 17 is : 0.34
# Health scores of Engine no. 18 is : 0.25
# Health scores of Engine no. 19 is : 0.73
# Health scores of Engine no. 20 is : 0.01
# Health scores of Engine no. 21 is : 0.77
# Health scores of Engine no. 22 is : 1
# Health scores of Engine no. 23 is : 0.9
# Health scores of Engine no. 24 is : 0.27
# Health scores of Engine no. 25 is : 1
# Health scores of Engine no. 26 is : 1
# Health scores of Engine no. 27 is : 0.9
# Health scores of Engine no. 28 is : 0.45
# Health scores of Engine no. 29 is : 0.63
# Health scores of Engine no. 30 is : 0.48
# Health scores of Engine no. 31 is : 0.01
# Health scores of Engine no. 32 is : 0.46
# Health scores of Engine no. 33 is : 0.3
# Health scores of Engine no. 34 is : 0.01
# Health scores of Engine no. 35 is : 0.01
# Health scores of Engine no. 36 is : 0.01
# Health scores of Engine no. 37 is : 0.16
# Health scores of Engine no. 38 is : 0.18
# Health scores of Engine no. 39 is : 1
# Health scores of Engine no. 40 is : 0.08
# Health scores of Engine no. 41 is : 0.25
# Health scores of Engine no. 42 is : 0.01
# Health scores of Engine no. 43 is : 0.32
# Health scores of Engine no. 44 is : 0.81
# Health scores of Engine no. 45 is : 0.46
# Health scores of Engine no. 46 is : 0.34
# Health scores of Engine no. 47 is : 0.52
# Health scores of Engine no. 48 is : 0.96
# Health scores of Engine no. 49 is : 0.01
# Health scores of Engine no. 50 is : 0.83
# Health scores of Engine no. 51 is : 0.68
# Health scores of Engine no. 52 is : 0.18
# Health scores of Engine no. 53 is : 0.15
# Health scores of Engine no. 54 is : 0.83
# Health scores of Engine no. 55 is : 0.7
# Health scores of Engine no. 56 is : 0.02
# Health scores of Engine no. 57 is : 0.52
# Health scores of Engine no. 58 is : 0.18
# Health scores of Engine no. 59 is : 1
# Health scores of Engine no. 60 is : 0.57
# Health scores of Engine no. 61 is : 0.14
# Health scores of Engine no. 62 is : 0.37
# Health scores of Engine no. 63 is : 0.34
# Health scores of Engine no. 64 is : 0.13
# Health scores of Engine no. 65 is : 1
# Health scores of Engine no. 66 is : 0.02
# Health scores of Engine no. 67 is : 1
# Health scores of Engine no. 68 is : 0.01
# Health scores of Engine no. 69 is : 1
# Health scores of Engine no. 70 is : 0.54
# Health scores of Engine no. 71 is : 0.93
# Health scores of Engine no. 72 is : 0.49
# Health scores of Engine no. 73 is : 0.93
# Health scores of Engine no. 74 is : 0.54
# Health scores of Engine no. 75 is : 0.86
# Health scores of Engine no. 76 is : 0.01
# Health scores of Engine no. 77 is : 0.14
# Health scores of Engine no. 78 is : 1
# Health scores of Engine no. 79 is : 0.93
# Health scores of Engine no. 80 is : 0.46
# Health scores of Engine no. 81 is : 0.01
# Health scores of Engine no. 82 is : 0.01
# Health scores of Engine no. 83 is : 0.88
# Health scores of Engine no. 84 is : 0.32
# Health scores of Engine no. 85 is : 0.75
# Health scores of Engine no. 86 is : 0.45
# Health scores of Engine no. 87 is : 1
# Health scores of Engine no. 88 is : 0.48
# Health scores of Engine no. 89 is : 0.49
# Health scores of Engine no. 90 is : 0.06
# Health scores of Engine no. 91 is : 0.07
# Health scores of Engine no. 92 is : 0.01
# Health scores of Engine no. 93 is : 0.21
# Health scores of Engine no. 94 is : 0.25
# Health scores of Engine no. 95 is : 0.96
# Health scores of Engine no. 96 is : 0.86
# Health scores of Engine no. 97 is : 0.58
# Health scores of Engine no. 98 is : 0.31
# Health scores of Engine no. 99 is : 0.95
# Health scores of Engine no. 100 is : 0.15

# %% [markdown]
# # 7. Analysing Prediction

# %%
a = y_test

# %%
my_pred = logistic_pred

# %%
actual = []
for i in range(len(a)):
    actual.append(a[i][0])

# %%
print(actual)
# Out:
# [112, 98, 69, 82, 91, 93, 91, 95, 111, 96, 97, 124, 95, 107, 83, 84, 50, 28, 87, 16, 57, 111, 113, 20, 145, 119, 66, 97, 90, 115, 8, 48, 106, 7, 11, 19, 21, 50, 142, 28, 18, 10, 59, 109, 114, 47, 135, 92, 21, 79, 114, 29, 26, 97, 137, 15, 103, 37, 114, 100, 21, 54, 72, 28, 128, 14, 77, 8, 121, 94, 118, 50, 131, 126, 113, 10, 34, 107, 63, 90, 8, 9, 137, 58, 118, 89, 116, 115, 136, 28, 38, 20, 85, 55, 128, 137, 82, 59, 117, 20]

# %%
overestimation = []
percentage_errors = [[],[],[],[],[],[],[],[],[],[],[]]
for i in range(len(my_pred)):
    percentage_error = ((my_pred[i]-actual[i])/actual[i])*100
#     print(abs(int(percentage_error/10)))
    print("For engine",i,"overestimated RUL is :",percentage_error)
    if abs(int(percentage_error/10)) < 10:
        percentage_errors[abs(int(percentage_error/10))].append(percentage_error)
    else:
        percentage_errors[10].append(percentage_error)
    overestimation.append(my_pred[i]-actual[i])
# Out:
# For engine 0 overestimated RUL is : [63.39285714]
# For engine 1 overestimated RUL is : [-53.06122449]
# For engine 2 overestimated RUL is : [-53.62318841]
# For engine 3 overestimated RUL is : [-30.48780488]
# For engine 4 overestimated RUL is : [-48.35164835]
# For engine 5 overestimated RUL is : [-40.86021505]
# For engine 6 overestimated RUL is : [-25.27472527]
# For engine 7 overestimated RUL is : [-41.05263158]
# For engine 8 overestimated RUL is : [-55.85585586]
# For engine 9 overestimated RUL is : [-41.66666667]
# For engine 10 overestimated RUL is : [-58.7628866]
# For engine 11 overestimated RUL is : [-52.41935484]
# For engine 12 overestimated RUL is : [-42.10526316]
# For engine 13 overestimated RUL is : [-51.40186916]
# For engine 14 overestimated RUL is : [18.07228916]
# For engine 15 overestimated RUL is : [-3.57142857]
# For engine 16 overestimated RUL is : [-32.]
# For engine 17 overestimated RUL is : [-10.71428571]
# For engine 18 overestimated RUL is : [-16.09195402]
# For engine 19 overestimated RUL is : [-93.75]
# For engine 20 overestimated RUL is : [35.0877193]
# For engine 21 overestimated RUL is : [11.71171171]
# For engine 22 overestimated RUL is : [-20.3539823]
# For engine 23 overestimated RUL is : [35.]
# For engine 24 overestimated RUL is : [-20.]
# For engine 25 overestimated RUL is : [-15.96638655]
# For engine 26 overestimated RUL is : [36.36363636]
# For engine 27 overestimated RUL is : [-53.60824742]
# For engine 28 overestimated RUL is : [-30.]
# For engine 29 overestimated RUL is : [-58.26086957]
# For engine 30 overestimated RUL is : [-87.5]
# For engine 31 overestimated RUL is : [-4.16666667]
# For engine 32 overestimated RUL is : [-71.69811321]
# For engine 33 overestimated RUL is : [-85.71428571]
# For engine 34 overestimated RUL is : [-90.90909091]
# For engine 35 overestimated RUL is : [-94.73684211]
# For engine 36 overestimated RUL is : [-23.80952381]
# For engine 37 overestimated RUL is : [-64.]
# For engine 38 overestimated RUL is : [19.01408451]
# For engine 39 overestimated RUL is : [-71.42857143]
# For engine 40 overestimated RUL is : [38.88888889]
# For engine 41 overestimated RUL is : [-90.]
# For engine 42 overestimated RUL is : [-45.76271186]
# For engine 43 overestimated RUL is : [-25.68807339]
# For engine 44 overestimated RUL is : [-59.64912281]
# For engine 45 overestimated RUL is : [-27.65957447]
# For engine 46 overestimated RUL is : [-61.48148148]
# For engine 47 overestimated RUL is : [4.34782609]
# For engine 48 overestimated RUL is : [-95.23809524]
# For engine 49 overestimated RUL is : [5.06329114]
# For engine 50 overestimated RUL is : [-40.35087719]
# For engine 51 overestimated RUL is : [-37.93103448]
# For engine 52 overestimated RUL is : [-42.30769231]
# For engine 53 overestimated RUL is : [-14.43298969]
# For engine 54 overestimated RUL is : [-48.90510949]
# For engine 55 overestimated RUL is : [-86.66666667]
# For engine 56 overestimated RUL is : [-49.51456311]
# For engine 57 overestimated RUL is : [-51.35135135]
# For engine 58 overestimated RUL is : [6.14035088]
# For engine 59 overestimated RUL is : [-43.]
# For engine 60 overestimated RUL is : [-33.33333333]
# For engine 61 overestimated RUL is : [-31.48148148]
# For engine 62 overestimated RUL is : [-52.77777778]
# For engine 63 overestimated RUL is : [-53.57142857]
# For engine 64 overestimated RUL is : [6.25]
# For engine 65 overestimated RUL is : [-85.71428571]
# For engine 66 overestimated RUL is : [32.46753247]
# For engine 67 overestimated RUL is : [-87.5]
# For engine 68 overestimated RUL is : [8.26446281]
# For engine 69 overestimated RUL is : [-42.55319149]
# For engine 70 overestimated RUL is : [-21.18644068]
# For engine 71 overestimated RUL is : [-2.]
# For engine 72 overestimated RUL is : [-29.00763359]
# For engine 73 overestimated RUL is : [-57.14285714]
# For engine 74 overestimated RUL is : [-23.89380531]
# For engine 75 overestimated RUL is : [-90.]
# For engine 76 overestimated RUL is : [-58.82352941]
# For engine 77 overestimated RUL is : [14.95327103]
# For engine 78 overestimated RUL is : [47.61904762]
# For engine 79 overestimated RUL is : [-48.88888889]
# For engine 80 overestimated RUL is : [-87.5]
# For engine 81 overestimated RUL is : [-88.88888889]
# For engine 82 overestimated RUL is : [-35.76642336]
# For engine 83 overestimated RUL is : [-44.82758621]
# For engine 84 overestimated RUL is : [-36.44067797]
# For engine 85 overestimated RUL is : [-49.43820225]
# For engine 86 overestimated RUL is : [4.31034483]
# For engine 87 overestimated RUL is : [-58.26086957]
# For engine 88 overestimated RUL is : [-63.97058824]
# For engine 89 overestimated RUL is : [-78.57142857]
# For engine 90 overestimated RUL is : [-81.57894737]
# For engine 91 overestimated RUL is : [-95.]
# For engine 92 overestimated RUL is : [-75.29411765]
# For engine 93 overestimated RUL is : [-54.54545455]
# For engine 94 overestimated RUL is : [-25.]
# For engine 95 overestimated RUL is : [-37.22627737]
# For engine 96 overestimated RUL is : [-29.26829268]
# For engine 97 overestimated RUL is : [-47.45762712]
# For engine 98 overestimated RUL is : [-18.8034188]
# For engine 99 overestimated RUL is : [-25.]

# %%
positive,negative,zeros = 0,0,0
for i in range(len(overestimation)):
    if overestimation[i] < 0:
        negative = negative + 1
    elif overestimation[i] > 0:
        positive = positive + 1
    else:
        zeros = zeros + 1

# %%
print("Overestimated RUL :",positive)
print("Underestimated RUL :",negative)
print("Correctly predicted RUL :",zeros)
# Out:
# Overestimated RUL : 17
# Underestimated RUL : 83
# Correctly predicted RUL : 0

# %%
for p in range(11):    
    if p < 10:
        print('Between',p*10,'and',(p+1)*10,'%','are :',len(percentage_errors[p]),'\n',percentage_errors[p],'\n\n')
    else:
        print('Over',p*10,'% are',len(percentage_errors[p]),'\n',percentage_errors[p],'\n\n')
# Out:
# Between 0 and 10 % are : 9
#  [array([-3.57142857]), array([-4.16666667]), array([4.34782609]), array([5.06329114]), array([6.14035088]), array([6.25]), array([8.26446281]), array([-2.]), array([4.31034483])]
#
#
# Between 10 and 20 % are : 9
#  [array([18.07228916]), array([-10.71428571]), array([-16.09195402]), array([11.71171171]), array([-15.96638655]), array([19.01408451]), array([-14.43298969]), array([14.95327103]), array([-18.8034188])]
#
#
# Between 20 and 30 % are : 12
#  [array([-25.27472527]), array([-20.3539823]), array([-20.]), array([-23.80952381]), array([-25.68807339]), array([-27.65957447]), array([-21.18644068]), array([-29.00763359]), array([-23.89380531]), array([-25.]), array([-29.26829268]), array([-25.])]
#
#
# Between 30 and 40 % are : 14
#  [array([-30.48780488]), array([-32.]), array([35.0877193]), array([35.]), array([36.36363636]), array([-30.]), array([38.88888889]), array([-37.93103448]), array([-33.33333333]), array([-31.48148148]), array([32.46753247]), array([-35.76642336]), array([-36.44067797]), array([-37.22627737])]
#
#
# Between 40 and 50 % are : 17
#  [array([-48.35164835]), array([-40.86021505]), array([-41.05263158]), array([-41.66666667]), array([-42.10526316]), array([-45.76271186]), array([-40.35087719]), array([-42.30769231]), array([-48.90510949]), array([-49.51456311]), array([-43.]), array([-42.55319149]), array([47.61904762]), array([-48.88888889]), array([-44.82758621]), array([-49.43820225]), array([-47.45762712])]
#
#
# Between 50 and 60 % are : 16
#  [array([-53.06122449]), array([-53.62318841]), array([-55.85585586]), array([-58.7628866]), array([-52.41935484]), array([-51.40186916]), array([-53.60824742]), array([-58.26086957]), array([-59.64912281]), array([-51.35135135]), array([-52.77777778]), array([-53.57142857]), array([-57.14285714]), array([-58.82352941]), array([-58.26086957]), array([-54.54545455])]
#
#
# Between 60 and 70 % are : 4
#  [array([63.39285714]), array([-64.]), array([-61.48148148]), array([-63.97058824])]
#
#
# Between 70 and 80 % are : 4
#  [array([-71.69811321]), array([-71.42857143]), array([-78.57142857]), array([-75.29411765])]
#
#
# Between 80 and 90 % are : 8
#  [array([-87.5]), array([-85.71428571]), array([-86.66666667]), array([-85.71428571]), array([-87.5]), array([-87.5]), array([-88.88888889]), array([-81.57894737])]
#
#
# Between 90 and 100 % are : 7
#  [array([-93.75]), array([-90.90909091]), array([-94.73684211]), array([-90.]), array([-95.23809524]), array([-90.]), array([-95.])]
#
#
# Over 100 % are 0
#  []
